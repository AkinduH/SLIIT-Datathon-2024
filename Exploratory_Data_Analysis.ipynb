# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_A = pd.read_csv("Datasets\df_A.csv")
df_B = pd.read_csv("Datasets\df_B.csv")

# %%
df_A
# Out:
#       LOCATION            DATE_TIME        DATE      TIME  SENSOR_ID  \
# 0            A  2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 1
# 1            A  2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 2
# 2            A  2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 3
# 3            A  2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 5
# 4            A  2020-05-15 00:00:00  2020-05-15  00:00:00  sensor 12
# ...        ...                  ...         ...       ...        ...
# 68773        A  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 37
# 68774        A  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 39
# 68775        A  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 42
# 68776        A  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 43
# 68777        A  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 44
#
#        DC_POWER  AC_POWER  DAILY_YIELD  TOTAL_YIELD  AMBIENT_TEMPERATURE  \
# ...
