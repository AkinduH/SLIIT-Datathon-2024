# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import holoviews as hv
from holoviews import opts

# %%
hv.extension('bokeh')  # Enable the Bokeh backend for interactive plots
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='aa2980ab-f499-47ce-ad85-d7a1b1dcc518'>
#   <div id="aaadd57d-5d1b-4690-9efe-25df898a8058" data-root-id="aa2980ab-f499-47ce-ad85-d7a1b1dcc518" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df_A = pd.read_csv("Datasets\df_A.csv")
df_B = pd.read_csv("Datasets\df_B.csv")

# %%
df_A
# Out:
#                  DATE_TIME        DATE      TIME  SENSOR_ID  DC_POWER  \
# 0      2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 1       0.0
# 1      2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 2       0.0
# 2      2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 3       0.0
# 3      2020-05-15 00:00:00  2020-05-15  00:00:00   sensor 5       0.0
# 4      2020-05-15 00:00:00  2020-05-15  00:00:00  sensor 12       0.0
# ...                    ...         ...       ...        ...       ...
# 68773  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 37       0.0
# 68774  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 39       0.0
# 68775  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 42       0.0
# 68776  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 43       0.0
# 68777  2020-06-17 23:45:00  2020-06-17  23:45:00  sensor 44       0.0
#
#        AC_POWER  DAILY_YIELD  DAILY_YIELD_diff  TOTAL_YIELD  TOTAL_YIELD_diff  \
# ...

# %%
def plot_data_on_time_series(df, features):  
    plots = []
    df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
    for feature in features:
        # Create a curve (line plot)
        curve = hv.Curve(
            df, 
            'DATE_TIME', 
            feature 
        ).opts(
            title=feature, xlabel='Date Time', ylabel=feature, width=800, height=300, 
            tools=['hover'], show_grid=True, xrotation=45
        )
        
        # Create scatter plot (dots for each data point)
        scatter = hv.Scatter(
            df, 
            'DATE_TIME', 
            feature 
        ).opts(
            size=5, color='red', tools=['hover'], show_grid=True
        )
        
        # Overlay the curve and scatter
        overlay = curve * scatter
        plots.append(overlay)
    return plots

# %%
Plot_df = df_A[(df_A['SENSOR_ID'] == 'sensor 1')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(Plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
Plot_df = df_B[(df_B['SENSOR_ID'] == 'sensor 6')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(Plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
# Filter the DataFrame for sensor 1 on 2020-05-15
plot_df = df_A[(df_A['SENSOR_ID'] == 'sensor 1') & (df_A['DATE'] == '2020-05-15')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
# Filter the DataFrame for sensor 6 on 2020-05-23
plot_df = df_B[(df_B['SENSOR_ID'] == 'sensor 6') & (df_B['DATE'] == '2020-05-23')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
# Filter the DataFrame for sensor 6 on 2020-05-18
plot_df = df_B[(df_B['SENSOR_ID'] == 'sensor 6') & (df_B['DATE'] == '2020-05-22')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
# Filter the DataFrame for sensor 6 on 2020-05-17
plot_df = df_B[(df_B['SENSOR_ID'] == 'sensor 6') & (df_B['DATE'] == '2020-05-17')]

# Define features to plot
features = ['DAILY_YIELD', 'TOTAL_YIELD', 'DC_POWER', 'AC_POWER', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plots = plot_data_on_time_series(plot_df, features)

# Combine plots vertically
layout = hv.Layout(plots).cols(1)

# Display Holoviews plot
layout
# Out:
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_10816\2675421589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DAILY_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (DAILY_YIELD)
#    .Overlay.II  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (TOTAL_YIELD)
#       .Scatter.I :Scatter   [DATE_TIME]   (TOTAL_YIELD)
#    .Overlay.III :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (DC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (DC_POWER)
#    .Overlay.IV  :Overlay
#       .Curve.I   :Curve   [DATE_TIME]   (AC_POWER)
#       .Scatter.I :Scatter   [DATE_TIME]   (AC_POWER)
# ...

# %%
# Get a list of unique sensor IDs
unique_sensors = df_A['SENSOR_ID'].unique()

# Create distribution plots for each sensor
plots = []
for sensor_id in unique_sensors:
    # Filter the DataFrame for the current sensor
    sensor_df = df_A[df_A['SENSOR_ID'] == sensor_id]
    
    # Create a distribution plot for DAILY_YIELD
    dist_plot = hv.Distribution(sensor_df['DAILY_YIELD']).opts(
        title=f"DAILY_YIELD {sensor_id}",
        xlabel="Value",
        ylabel="Density",
        width=300,  # Adjust width for fitting multiple plots
        height=300,
        tools=['hover'],
        show_grid=True
    )
    plots.append(dist_plot)

# Combine plots in a grid layout
grid_layout = hv.Layout(plots).cols(4)  # Adjust the number of columns as needed

# Display all plots
grid_layout
# Out:
# :Layout
#    .Distribution.I     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.II    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.III   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.IV    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.V     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VI    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VII   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VIII  :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.IX    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.X     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XI    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XII   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XIII  :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XIV   :Distribution   [DAILY_YIELD]   (Density)
# ...

# %%
# Get a list of unique sensor IDs
unique_sensors = df_B['SENSOR_ID'].unique()

# Create distribution plots for each sensor
plots = []
for sensor_id in unique_sensors:
    # Filter the DataFrame for the current sensor
    sensor_df = df_B[df_B['SENSOR_ID'] == sensor_id]
    
    # Create a distribution plot for DAILY_YIELD
    dist_plot = hv.Distribution(sensor_df['DAILY_YIELD']).opts(
        title=f"DAILY_YIELD {sensor_id}",
        xlabel="Value",
        ylabel="Density",
        width=300,  # Adjust width for fitting multiple plots
        height=300,
        tools=['hover'],
        show_grid=True
    )
    plots.append(dist_plot)

# Combine plots in a grid layout
grid_layout = hv.Layout(plots).cols(4)  # Adjust the number of columns as needed

# Display all plots
grid_layout
# Out:
# :Layout
#    .Distribution.I     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.II    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.III   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.IV    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.V     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VI    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VII   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.VIII  :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.IX    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.X     :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XI    :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XII   :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XIII  :Distribution   [DAILY_YIELD]   (Density)
#    .Distribution.XIV   :Distribution   [DAILY_YIELD]   (Density)
# ...

# %%
A1_df = df_A[(df_A['SENSOR_ID'] == 'sensor 1')].copy()
A2_df = df_A[(df_A['SENSOR_ID'] == 'sensor 2')].copy()
A3_df = df_A[(df_A['SENSOR_ID'] == 'sensor 3')].copy()
A5_df = df_A[(df_A['SENSOR_ID'] == 'sensor 5')].copy()
A12_df = df_A[(df_A['SENSOR_ID'] == 'sensor 12')].copy()
A19_df = df_A[(df_A['SENSOR_ID'] == 'sensor 19')].copy()
A20_df = df_A[(df_A['SENSOR_ID'] == 'sensor 20')].copy()
A23_df = df_A[(df_A['SENSOR_ID'] == 'sensor 23')].copy()
A24_df = df_A[(df_A['SENSOR_ID'] == 'sensor 24')].copy()
A25_df = df_A[(df_A['SENSOR_ID'] == 'sensor 25')].copy()
A26_df = df_A[(df_A['SENSOR_ID'] == 'sensor 26')].copy()
A27_df = df_A[(df_A['SENSOR_ID'] == 'sensor 27')].copy()
A28_df = df_A[(df_A['SENSOR_ID'] == 'sensor 28')].copy()
A32_df = df_A[(df_A['SENSOR_ID'] == 'sensor 32')].copy()
A34_df = df_A[(df_A['SENSOR_ID'] == 'sensor 34')].copy()
A36_df = df_A[(df_A['SENSOR_ID'] == 'sensor 36')].copy()
A37_df = df_A[(df_A['SENSOR_ID'] == 'sensor 37')].copy()
A39_df = df_A[(df_A['SENSOR_ID'] == 'sensor 39')].copy()
A42_df = df_A[(df_A['SENSOR_ID'] == 'sensor 42')].copy()
A43_df = df_A[(df_A['SENSOR_ID'] == 'sensor 43')].copy()
A44_df = df_A[(df_A['SENSOR_ID'] == 'sensor 44')].copy()
A45_df = df_A[(df_A['SENSOR_ID'] == 'sensor 22')].copy()

location_A =[A1_df, A2_df, A3_df, A5_df, A12_df, A19_df, A20_df, A23_df, A24_df, A25_df, A26_df, A27_df, A28_df, A32_df, A34_df, A36_df, A37_df, A39_df, A42_df, A43_df, A44_df, A45_df]

# %%
B4_df = df_B[(df_B['SENSOR_ID'] == 'sensor 4')].copy()
B6_df = df_B[(df_B['SENSOR_ID'] == 'sensor 6')].copy()
B7_df = df_B[(df_B['SENSOR_ID'] == 'sensor 7')].copy()
B8_df = df_B[(df_B['SENSOR_ID'] == 'sensor 8')].copy()
B9_df = df_B[(df_B['SENSOR_ID'] == 'sensor 9')].copy()
B10_df = df_B[(df_B['SENSOR_ID'] == 'sensor 10')].copy()
B11_df = df_B[(df_B['SENSOR_ID'] == 'sensor 11')].copy()
B13_df = df_B[(df_B['SENSOR_ID'] == 'sensor 13')].copy()
B14_df = df_B[(df_B['SENSOR_ID'] == 'sensor 14')].copy()
B15_df = df_B[(df_B['SENSOR_ID'] == 'sensor 15')].copy()
B16_df = df_B[(df_B['SENSOR_ID'] == 'sensor 16')].copy()
B17_df = df_B[(df_B['SENSOR_ID'] == 'sensor 17')].copy()
B18_df = df_B[(df_B['SENSOR_ID'] == 'sensor 18')].copy()
B21_df = df_B[(df_B['SENSOR_ID'] == 'sensor 21')].copy()
B29_df = df_B[(df_B['SENSOR_ID'] == 'sensor 29')].copy()
B30_df = df_B[(df_B['SENSOR_ID'] == 'sensor 30')].copy()
B31_df = df_B[(df_B['SENSOR_ID'] == 'sensor 31')].copy()
B33_df = df_B[(df_B['SENSOR_ID'] == 'sensor 33')].copy()
B35_df = df_B[(df_B['SENSOR_ID'] == 'sensor 35')].copy()
B38_df = df_B[(df_B['SENSOR_ID'] == 'sensor 38')].copy()
B40_df = df_B[(df_B['SENSOR_ID'] == 'sensor 40')].copy()
B41_df = df_B[(df_B['SENSOR_ID'] == 'sensor 41')].copy()

location_B =[B4_df, B6_df, B8_df, B9_df, B10_df, B11_df, B13_df, B14_df, B15_df, B16_df, B17_df, B18_df, B21_df, B29_df, B30_df, B31_df, B33_df, B35_df, B38_df, B40_df, B41_df]

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    X = X.copy()
    
    # Convert datetime columns to numeric
    for colname in X.select_dtypes(["datetime64"]):
        X[colname] = X[colname].view(int)  # Convert datetime to timestamp integers
    
    # Factorize categorical columns
    for colname in X.select_dtypes(["object", "category"]):
        X[colname], _ = X[colname].factorize()
    
    # All discrete features should now have integer dtypes
    discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    
    # Compute mutual information scores
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    
    return mi_scores

def plot_mi_scores(scores, title):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title(title)
    plt.show()

# %%
Mi_df = A1_df.copy()
Mi_df.dropna(inplace=True)
X = Mi_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'TIME', 'DC_POWER', 'AC_POWER']]
y = Mi_df['TOTAL_YIELD_diff']

mi_scores = make_mi_scores(X, y)

print(mi_scores)

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores, "MI Scores for TOTAL_YIELD_diff")
# Out:
# AC_POWER               1.495363
# DC_POWER               1.491836
# IRRADIATION            1.471474
# TIME                   1.221090
# MODULE_TEMPERATURE     1.039978
# AMBIENT_TEMPERATURE    0.486786
# Name: MI Scores, dtype: float64

# %%
Mi_df = A2_df.copy()
Mi_df.dropna(inplace=True)
X = Mi_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'TIME', 'DC_POWER', 'AC_POWER']]
y = Mi_df['TOTAL_YIELD_diff']

mi_scores = make_mi_scores(X, y)

print(mi_scores)

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores, "MI Scores for TOTAL_YIELD_diff")
# Out:
# AC_POWER               1.547729
# IRRADIATION            1.547637
# DC_POWER               1.521607
# TIME                   1.236443
# MODULE_TEMPERATURE     1.107884
# AMBIENT_TEMPERATURE    0.499944
# Name: MI Scores, dtype: float64

# %%
Mi_df = B4_df.copy()
Mi_df.dropna(inplace=True)
X = Mi_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'TIME', 'DC_POWER', 'AC_POWER']]
y = Mi_df['TOTAL_YIELD_diff']

mi_scores = make_mi_scores(X, y)

print(mi_scores)

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores, "MI Scores for TOTAL_YIELD_diff")
# Out:
# TIME                   1.025181
# IRRADIATION            0.364458
# DC_POWER               0.359765
# AC_POWER               0.353933
# MODULE_TEMPERATURE     0.206760
# AMBIENT_TEMPERATURE    0.103048
# Name: MI Scores, dtype: float64

# %%
Mi_df = B6_df.copy()
Mi_df.dropna(inplace=True)
X = Mi_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'TIME', 'DC_POWER', 'AC_POWER']]
y = Mi_df['TOTAL_YIELD_diff']

mi_scores = make_mi_scores(X, y)

print(mi_scores)

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores, "MI Scores for TOTAL_YIELD_diff")
# Out:
# TIME                   0.807284
# AC_POWER               0.283483
# DC_POWER               0.282736
# IRRADIATION            0.266760
# MODULE_TEMPERATURE     0.023145
# AMBIENT_TEMPERATURE    0.017088
# Name: MI Scores, dtype: float64

# %%
# # Loop through each DataFrame and plot MI scores
# for idx, df in enumerate(location_A, 1):
#     Mi_df = df.copy()
#     Mi_df.dropna(inplace=True)

#     # Define features and target
#     X = Mi_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'TIME', 'DC_POWER', 'AC_POWER']]
#     y = Mi_df['TOTAL_YIELD_diff']

#     # Calculate MI scores
#     mi_scores = make_mi_scores(X, y)


#     plot_mi_scores(mi_scores, f"MI Scores for DataFrame {idx}")

# %%
import seaborn as sns

X = A1_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'DC_POWER', 'AC_POWER', 'DAILY_YIELD_diff', 'TOTAL_YIELD_diff']]

cor_mat = X.corr(method="pearson")

mask = np.triu(np.ones_like(cor_mat))

plt.figure(figsize=(25, 20))
sns.heatmap(cor_mat, annot=True, fmt=".2f", cmap="coolwarm", mask=mask)
plt.show()

# %%
import seaborn as sns

X = A12_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'DC_POWER', 'AC_POWER', 'DAILY_YIELD_diff', 'TOTAL_YIELD_diff']]

cor_mat = X.corr(method="pearson")

mask = np.triu(np.ones_like(cor_mat))

plt.figure(figsize=(25, 20))
sns.heatmap(cor_mat, annot=True, fmt=".2f", cmap="coolwarm", mask=mask)
plt.show()

# %%
import seaborn as sns

X = B4_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'DC_POWER', 'AC_POWER', 'DAILY_YIELD_diff', 'TOTAL_YIELD_diff']]

cor_mat = X.corr(method="pearson")

mask = np.triu(np.ones_like(cor_mat))

plt.figure(figsize=(25, 20))
sns.heatmap(cor_mat, annot=True, fmt=".2f", cmap="coolwarm", mask=mask)
plt.show()

# %%
import seaborn as sns

X = B18_df[['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION', 'DC_POWER', 'AC_POWER', 'DAILY_YIELD_diff', 'TOTAL_YIELD_diff']]

cor_mat = X.corr(method="pearson")

mask = np.triu(np.ones_like(cor_mat))

plt.figure(figsize=(25, 20))
sns.heatmap(cor_mat, annot=True, fmt=".2f", cmap="coolwarm", mask=mask)
plt.show()

# %%
# List of DataFrame names corresponding to location_A
df_names = [
    "A1_df", "A2_df", "A3_df", "A5_df", "A12_df", "A19_df", "A20_df", 
    "A23_df", "A24_df", "A25_df", "A26_df", "A27_df", "A28_df", 
    "A32_df", "A34_df", "A36_df", "A37_df", "A39_df", "A42_df", 
    "A43_df", "A44_df", "A45_df"
]

# Save each DataFrame to a CSV file
for df_name, df in zip(df_names, location_A):
    df.drop('SENSOR_ID', axis=1, inplace=True)
    csv_filename = f"{df_name}.csv"
    df.to_csv(f"Datasets\{csv_filename}", index=False)

# %%
# List of DataFrame names corresponding to location_B
df_names_B = [
    "B4_df", "B6_df", "B8_df", "B9_df", "B10_df", "B11_df", "B13_df", 
    "B14_df", "B15_df", "B16_df", "B17_df", "B18_df", "B21_df", 
    "B29_df", "B30_df", "B31_df", "B33_df", "B35_df", "B38_df", 
    "B40_df", "B41_df"
]

# Save each DataFrame to a CSV file
for df_name, df in zip(df_names_B, location_B):
    df.drop('SENSOR_ID', axis=1, inplace=True)
    csv_filename = f"{df_name}.csv"
    df.to_csv(f"Datasets\{csv_filename}", index=False)
